# %%
import json
import pandas as pd
from text_processing import find_value_by_key,find_values_by_key
from difflib import SequenceMatcher

with open("arxiv.json", 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# %%
papers_df = pd.read_json('paper_2024_11_19.json', orient="records", lines=True)
authors_df = pd.read_json('author_2024_11_19.json', orient="records", lines=True)
affiliations_df = pd.read_json('affiliation_2024_11_19.json', orient="records", lines=True)

# %%
authors_df.columns
# Out:
# Index(['auid', 'given-name', 'initials', 'surname', 'indexed-name',
#        'affliation', 'paper'],
#       dtype='object')

# %%
def check_author_exist(input_name,df,new_author):
    given_name, surname = input_name.split()[0],input_name.split()[-1]
    existing = df[(df['given-name'] == given_name) & (df['surname'] == surname)]

    if existing.empty:
        new_id = f"S{new_author:09d}"  # Format new id as s00xxx
        new_row = pd.DataFrame({'auid': [new_id], 'given-name': [given_name], 'surname': [surname]})
        df = pd.concat([df, new_row], ignore_index=True)
        new_author += 1  # Increment the author number for next use
    else:
        new_id = existing['auid'].iloc[0]
        print(given_name, surname)
    return new_id,df,new_author

# %%
new_author = 1
new_affiliation = 1
for data in find_value_by_key(json_data, "entry"):
    paper_id = data["id"].split("/")[-1]
    authors = []
    paper_affs = []
    if not isinstance(data["author"], list):
        aus = [data["author"]]
    else:
        aus = data["author"]
    for name in aus:
        # Handle "name" and "surname" or "indexed-name"
        if "." in name["name"].split()[-1]:  # Handle the case where initials are in "name"
            indexed_name = name["name"]
            surname = indexed_name.split()[0]
            initials = indexed_name.split()[1]
            given_name = None
        else:  # Handle the standard case
            given_name, surname = name["name"].split()[0], name["name"].split()[-1]
            initials = f"{given_name[0]}."
            indexed_name = f"{surname} {given_name[0]}."

        existing = authors_df[
            (authors_df["given-name"] == given_name) & (authors_df["surname"] == surname)
        ]
        if existing.empty:
            if "arxiv:affiliation" in name:
                if not isinstance(name["arxiv:affiliation"], list):
                    affs = [name["arxiv:affiliation"]["#text"]]
                else:
                    affs = [aff["#text"] for aff in name["arxiv:affiliation"]]
                affiliations = []
                for aff_name in affs:
                    # Check if any name in the DataFrame matches aff_name (case-insensitively)
                    match_found = False
                    for _, row in affiliations_df.iterrows():
                        if "INFN" in aff_name or "Academy of Science" in aff_name:
                            if aff_name == row["name"]:
                                match_found = True
                                matched_affid = row["affid"]
                                # print(f"Match found for '{aff_name}': {row['name']}")
                                break
                        elif aff_name in row["name"]:
                            if len(aff_name) > len(row["name"]) / 2:
                                match_found = True
                                matched_affid = row["affid"]
                                break
                        elif row["name"] in aff_name:
                            if len(aff_name) / 2 < len(row["name"]):
                                matched_affid = row["affid"]
                                match_found = True
                                break

                    if not match_found:
                        # If no sufficient match, add a new row to the DataFrame
                        new_aff_id = f"S{new_affiliation:07d}"
                        new_affiliation += 1
                        new_row = {"affid": new_aff_id, "name": aff_name}
                        affiliations_df = pd.concat([affiliations_df, pd.DataFrame([new_row])], ignore_index=True)
                        matched_affid = new_aff_id
                    affiliations.append(matched_affid)
                    if matched_affid not in paper_affs:
                        paper_affs.append(matched_affid)

            new_id = f"S{new_author:09d}"
            new_row = pd.DataFrame({
                "auid": [new_id],
                "given-name": [given_name],
                "surname": [surname],
                "indexed-name": [indexed_name],
                "paper": [[paper_id]],
                "affiliation": [affiliations],
            })
            authors_df = pd.concat([authors_df, new_row], ignore_index=True)
            new_author += 1
        else:
            new_id = existing["auid"].iloc[0]
            idx = existing.index[0]
            authors_df.at[idx, "paper"] = authors_df.at[idx, "paper"] + [paper_id]
        authors.append(str(new_id))
    new_row = pd.DataFrame({
        "id": [paper_id],
        "title": [data["title"].replace("\n", " ")],
        "description": [data["summary"].replace("\n", " ")],
        "date": [data["published"]],
        "year": [data["published"].split("-")[0]],
        "authors": [authors],
        "affiliations": [paper_affs],
    })
    papers_df = pd.concat([papers_df, new_row], ignore_index=True)

# %%
name
# Out:
# {'name': 'Danny Hermelin'}

# %%
data["author"]
# Out:
# [{'name': 'Klaus Heeger'}, {'name': 'Danny Hermelin'}]

# %%
affiliations_df.tail(50)
# Out:
#           affid city                                               name  \
# 12245  S0000127  NaN  Laboratoire de Physique de l'École Normale Sup...
# 12246  S0000128  NaN  Observatoire de Paris, Université PSL, Sorbonn...
# 12247  S0000129  NaN  Astrophysics Group, Blackett Laboratory, Imper...
# 12248  S0000130  NaN  Scuola Normale Superiore, Piazza dei Cavalieri...
# 12249  S0000131  NaN  Dipartimento di Fisica e Scienze della Terra, ...
# 12250  S0000132  NaN  Dipartimento di Fisica - Sezione di Astronomia...
# 12251  S0000133  NaN  NASA Ames Research Center, Moffett Field, CA 9...
# 12252  S0000134  NaN  Kavli Institute for Particle Astrophysics \& C...
# 12253  S0000135  NaN  Minnesota Institute for Astrophysics, Universi...
# 12254  S0000136  NaN  INAF, Istituto di Radioastronomia, Via Piero G...
# 12255  S0000137  NaN  Institute Lorentz, Leiden University, Niels Bo...
# 12256  S0000138  NaN  Institute for Astronomy, University of Hawaii,...
# 12257  S0000139  NaN  Department of Physics \& Astronomy, University...
# 12258  S0000140  NaN  Dept. of Physics, IIT Hyderabad, Kandi, Telang...
# 12259  S0000141  NaN  Department of Astronomy \& Physics and Institu...
# 12260  S0000142  NaN  Departamento Física Aplicada, Universidad Poli...
# 12261  S0000143  NaN  Dipartimento di Fisica, Università degli studi...
# 12262  S0000144  NaN  Ruhr University Bochum, Faculty of Physics and...
# 12263  S0000145  NaN               Instituto de Astrofísica de Canarias
# 12264  S0000146  NaN  Université Paris-Cité, 5 Rue Thomas Mann, 7501...
# 12265  S0000147  NaN  Université PSL, Observatoire de Paris, Sorbonn...
# 12266  S0000148  NaN  Univ. Grenoble Alpes, CNRS, Grenoble INP, LPSC...
# 12267  S0000149  NaN  Department of Physics and Astronomy, Vesilinna...
# 12268  S0000150  NaN                    Serco for European Space Agency
# 12269  S0000151  NaN  Oskar Klein Centre for Cosmoparticle Physics, ...
# 12270  S0000152  NaN  Dipartimento di Fisica, Sapienza Università di...
# 12271  S0000153  NaN  Centro de Astrofísica da Universidade do Porto...
# 12272  S0000154  NaN  Dipartimento di Fisica, Università di Roma Tor...
# 12273  S0000155  NaN  INFN, Sezione di Roma 2, Via della Ricerca Sci...
# 12274  S0000156  NaN  Department of Mathematics and Physics E. De Gi...
# 12275  S0000157  NaN  INAF-Sezione di Lecce, c/o Dipartimento Matema...
# 12276  S0000158  NaN  INFN, Sezione di Lecce, Via per Arnesano, CP-1...
# 12277  S0000159  NaN  Department of Astrophysics, University of Zuri...
# 12278  S0000160  NaN  ASTRON, the Netherlands Institute for Radio As...
# 12279  S0000161  NaN  Department of Astrophysical Sciences, Peyton H...
# 12280  S0000162  NaN  Niels Bohr Institute, University of Copenhagen...
# 12281  S0000163  NaN                                              Peter
# 12282  S0000164  NaN                                JLQCD Collaboration
# 12283  S0000165  NaN                                         HIAS, UCAS
# 12284  S0000166  NaN                                                CdF
# 12285  S0000167  NaN                                               ACTE
# 12286  S0000168  NaN                                               CRNS
# 12287  S0000169  NaN                                              ISIMS
# 12288  S0000170  NaN                                              LINCS
# 12289  S0000171  NaN  Paul C. Lauterbur Research Center for Biomedic...
# 12290  S0000172  NaN  University of Chinese Academy of Sciences, Bei...
# 12291  S0000173  NaN                                   Technion, Israel
# 12292  S0000174  NaN  Department of Physics & Astronomy McMaster Uni...
# 12293  S0000175  NaN      Universitat Heidelberg Zentrum fur Astronomie
# 12294  S0000176  NaN                Max Planck Institute fur Astronomie
#
#       country  paper_count
# 12245     NaN          NaN
# 12246     NaN          NaN
# 12247     NaN          NaN
# 12248     NaN          NaN
# 12249     NaN          NaN
# 12250     NaN          NaN
# 12251     NaN          NaN
# 12252     NaN          NaN
# 12253     NaN          NaN
# 12254     NaN          NaN
# 12255     NaN          NaN
# 12256     NaN          NaN
# 12257     NaN          NaN
# 12258     NaN          NaN
# 12259     NaN          NaN
# 12260     NaN          NaN
# 12261     NaN          NaN
# 12262     NaN          NaN
# 12263     NaN          NaN
# 12264     NaN          NaN
# 12265     NaN          NaN
# 12266     NaN          NaN
# 12267     NaN          NaN
# 12268     NaN          NaN
# 12269     NaN          NaN
# 12270     NaN          NaN
# 12271     NaN          NaN
# 12272     NaN          NaN
# 12273     NaN          NaN
# 12274     NaN          NaN
# 12275     NaN          NaN
# 12276     NaN          NaN
# 12277     NaN          NaN
# 12278     NaN          NaN
# 12279     NaN          NaN
# 12280     NaN          NaN
# 12281     NaN          NaN
# 12282     NaN          NaN
# 12283     NaN          NaN
# 12284     NaN          NaN
# 12285     NaN          NaN
# 12286     NaN          NaN
# 12287     NaN          NaN
# 12288     NaN          NaN
# 12289     NaN          NaN
# 12290     NaN          NaN
# 12291     NaN          NaN
# 12292     NaN          NaN
# 12293     NaN          NaN
# 12294     NaN          NaN

# %%
papers_df.tail(50)
# Out:
#                  id                                              title  \
# 20490  2401.01691v1  2-Rainbow domination number of circulant graph...
# 20491  2401.01692v1  Predicting challenge moments from students' di...
# 20492  2401.01693v1  AID-DTI: Accelerating High-fidelity Diffusion ...
# 20493  2401.01694v2   Images of black holes viewed by distant observer
# 20494  2401.01695v3                     Approximation in Hölder Spaces
# 20495  2401.01696v1  Von Neumann entropy of the angle operator betw...
# 20496  2401.01697v3  Consideration of non-phase-matched nonlinear e...
# 20497  2401.01698v2  Patterns of Persistence and Diffusibility acro...
# 20498  2401.01699v2  WordArt Designer API: User-Driven Artistic Typ...
# 20499  2401.01700v1  Tulczyjew triple on the Atiyah algebroid with ...
# 20500  2401.01701v3  De-Hallucinator: Mitigating LLM Hallucinations...
# 20501  2401.01702v1  Image Sculpting: Precise Object Editing with 3...
# 20502  2401.01703v1  Proposal of detecting topological transition o...
# 20503  2401.01704v1  Global Well-posedness for 2D non-resistive MHD...
# 20504  2401.01705v2                f(R) gravity with spacetime torsion
# 20505  2401.01706v2  Transverse momentum balance of dijets in Xe+Xe...
# 20506  2401.01707v2  Explaining supernova remnant G352.7-0.1 as a p...
# 20507  2401.01708v1  Exploration of the Muon $g-2$ and Light Dark M...
# 20508  2401.01709v1  Local well-posedness of a coupled Jordan-Moore...
# 20509  2401.01710v1  EPA: Neural Collapse Inspired Robust Out-of-Di...
# 20510  2401.01711v1  Evaluating Large Language Models in Semantic P...
# 20511  2401.01712v1  Relativistically invariant encoding of quantum...
# 20512  2401.01713v1  Multiple testing of interval composite null hy...
# 20513  2401.01714v1  Sharp weighted inequalities for iterated commu...
# 20514  2401.01715v2  HEOM-QUICK2: a general-purpose simulator for f...
# 20515  2401.01716v1           On the connected (sub)partition polytope
# 20516  2401.01717v1  Fact-checking based fake news detection: a review
# 20517  2401.01718v1  RHDLPP: A multigroup radiation hydrodynamics c...
# 20518  2401.01719v4  Structural dynamics and optimal transport of a...
# 20519  2401.01720v1  Local Adaptive Clustering Based Image Matching...
# 20520  2401.01721v1  Limited Feedback on Measurements: Sharing a Co...
# 20521  2401.01722v3       Splitting Methods for differential equations
# 20522  2401.01723v2  A determinantal formula for orthosymplectic Sc...
# 20523  2401.01724v1  Lightweight Adaptive Feature De-drifting for C...
# 20524  2401.01725v2  KK-duality for the Cuntz-Pimsner algebras of T...
# 20525  2401.01726v1  An accurate reaction-diffusion limit to the sp...
# 20526  2401.01727v1   Asymmetric mode-pairing quantum key distribution
# 20527  2401.01728v2  Ravnest: Decentralized Asynchronous Training o...
# 20528  2401.01729v1  Development Of Impedance and Capacitance based...
# 20529  2401.01730v1  STAF: 3D Human Mesh Recovery from Video with S...
# 20530  2401.01731v3  Extracting double-quantum coherence in two-dim...
# 20531  2401.01732v1                       Task and Explanation Network
# 20532  2401.01733v1  Investigating the Suitability of Concept Drift...
# 20533  2401.01734v2  Learning Keypoints for Robotic Cloth Manipulat...
# 20534  2401.01735v1          Economics Arena for Large Language Models
# 20535  2401.01736v2  Few-shot Adaptation of Multi-modal Foundation ...
# 20536  2401.01737v1  Necessary conditions for the formation of fila...
# 20537  2401.01738v1  Integrated Sensing and Communication with Mass...
# 20538  2401.01739v2  A Soft Continuum Robot with Self-Controllable ...
# 20539  2401.01740v1  Minimizing the Weighted Number of Tardy Jobs i...
#
#                                              description publishername  \
# 20490  Let $k$ be a positive integer. A $k$-rainbow d...           NaN
# 20491  Effective collaboration requires groups to str...           NaN
# 20492  Deep learning has shown great potential in acc...           NaN
# 20493  We describe the possible forms of black hole i...           NaN
# 20494  We introduce new vanishing subspaces of the ho...           NaN
# 20495  Given a pair of intermediate $C^*$-subalgebras...           NaN
# 20496  Femtosecond optical parametric oscillators (OP...           NaN
# 20497  Language similarities can be caused by genetic...           NaN
# 20498  This paper introduces the WordArt Designer API...           NaN
# 20499  The Tulczyjew triple on a principal bundle wit...           NaN
# 20500  Large language models (LLMs) trained on datase...           NaN
# 20501  We present Image Sculpting, a new framework fo...           NaN
# 20502  The braiding operations of quantum states have...           NaN
# 20503  This paper focuses on the initial boundary val...           NaN
# 20504  The duality between a higher curvature $f(R)$ ...           NaN
# 20505  We present a theoretical study of the medium m...           NaN
# 20506  I identify a point-symmetric morphology of the...           NaN
# 20507  We report on a search for a new $Z'$ ($L_\mu-L...           NaN
# 20508  In this work, we investigate a mathematical mo...           NaN
# 20509  Out-of-distribution (OOD) detection plays a cr...           NaN
# 20510  Conversational question answering systems ofte...           NaN
# 20511  In this work, we provide a detailed analysis o...           NaN
# 20512  One class of statistical hypothesis testing pr...           NaN
# 20513  In this paper, the sharp quantitative weighted...           NaN
# 20514  Many-body open quantum systems (OQS) have a pr...           NaN
# 20515  Let $k$ be a positive integer and let $G$ be a...           NaN
# 20516  This paper reviews and summarizes the research...           NaN
# 20517  We introduce the RHDLPP, a flux-limited multig...           NaN
# 20518  We study the spontaneous configuration transit...           NaN
# 20519  Monitoring cameras are extensively utilized in...           NaN
# 20520  Discrete Fourier transform (DFT) codebook-base...           NaN
# 20521  This overview is devoted to splitting methods,...           NaN
# 20522  We prove a new determinantal formula for the c...           NaN
# 20523  JPEG is a widely used compression scheme to ef...           NaN
# 20524  We prove that the Cuntz-Pimsner algebra of eve...           NaN
# 20525  We resolve a long standing question regarding ...           NaN
# 20526  Mode-pairing quantum key distribution (MP-QKD)...           NaN
# 20527  Modern deep learning models, growing larger an...           NaN
# 20528  Electrical Impedance Spectroscopy (EIS) techni...           NaN
# 20529  The recovery of 3D human mesh from monocular i...           NaN
# 20530  Two-dimensional electronic spectroscopy (2DES)...           NaN
# 20531  Explainability in deep networks has gained inc...           NaN
# 20532  Leakages are a major risk in water distributio...           NaN
# 20533  Assistive robots should be able to wash, fold ...           NaN
# 20534  Large language models (LLMs) have been extensi...           NaN
# 20535  Multi-modal (vision-language) models, such as ...           NaN
# 20536  Star formation takes place in filamentary mole...           NaN
# 20537  Benefitting from the vast spatial degrees of f...           NaN
# 20538  This paper introduces a new type of soft conti...           NaN
# 20539  We consider the $1||\sum w_J U_j$ problem, the...           NaN
#
#       copyright_type                  date  year class  \
# 20490            NaN  2024-01-03T11:49:46Z  2024   NaN
# 20491            NaN  2024-01-03T11:54:30Z  2024   NaN
# 20492            NaN  2024-01-03T11:54:48Z  2024   NaN
# 20493            NaN  2024-01-03T11:55:03Z  2024   NaN
# 20494            NaN  2024-01-03T11:55:43Z  2024   NaN
# 20495            NaN  2024-01-03T12:00:50Z  2024   NaN
# 20496            NaN  2024-01-03T12:01:42Z  2024   NaN
# 20497            NaN  2024-01-03T12:05:38Z  2024   NaN
# 20498            NaN  2024-01-03T12:06:02Z  2024   NaN
# 20499            NaN  2024-01-03T12:07:35Z  2024   NaN
# 20500            NaN  2024-01-03T12:09:43Z  2024   NaN
# 20501            NaN  2024-01-02T18:59:35Z  2024   NaN
# 20502            NaN  2024-01-03T12:13:08Z  2024   NaN
# 20503            NaN  2024-01-03T12:13:13Z  2024   NaN
# 20504            NaN  2024-01-03T12:15:35Z  2024   NaN
# 20505            NaN  2024-01-03T12:17:24Z  2024   NaN
# 20506            NaN  2024-01-03T12:19:28Z  2024   NaN
# 20507            NaN  2024-01-03T12:23:42Z  2024   NaN
# 20508            NaN  2024-01-03T12:25:00Z  2024   NaN
# 20509            NaN  2024-01-03T12:25:18Z  2024   NaN
# 20510            NaN  2024-01-03T12:28:33Z  2024   NaN
# 20511            NaN  2024-01-03T12:29:21Z  2024   NaN
# 20512            NaN  2024-01-03T12:33:34Z  2024   NaN
# 20513            NaN  2024-01-03T12:41:14Z  2024   NaN
# 20514            NaN  2024-01-03T12:44:46Z  2024   NaN
# 20515            NaN  2024-01-03T12:45:09Z  2024   NaN
# 20516            NaN  2024-01-03T12:47:02Z  2024   NaN
# 20517            NaN  2024-01-03T12:49:46Z  2024   NaN
# 20518            NaN  2024-01-03T12:51:07Z  2024   NaN
# 20519            NaN  2024-01-03T12:54:31Z  2024   NaN
# 20520            NaN  2024-01-03T12:55:24Z  2024   NaN
# 20521            NaN  2024-01-03T12:57:06Z  2024   NaN
# 20522            NaN  2024-01-03T13:01:23Z  2024   NaN
# 20523            NaN  2024-01-03T13:03:44Z  2024   NaN
# 20524            NaN  2024-01-03T13:04:49Z  2024   NaN
# 20525            NaN  2024-01-03T13:05:29Z  2024   NaN
# 20526            NaN  2024-01-03T13:06:29Z  2024   NaN
# 20527            NaN  2024-01-03T13:07:07Z  2024   NaN
# 20528            NaN  2024-01-03T13:07:09Z  2024   NaN
# 20529            NaN  2024-01-03T13:07:14Z  2024   NaN
# 20530            NaN  2024-01-03T13:11:53Z  2024   NaN
# 20531            NaN  2024-01-03T13:11:59Z  2024   NaN
# 20532            NaN  2024-01-03T13:12:04Z  2024   NaN
# 20533            NaN  2024-01-03T13:16:38Z  2024   NaN
# 20534            NaN  2024-01-03T13:18:24Z  2024   NaN
# 20535            NaN  2024-01-03T13:19:14Z  2024   NaN
# 20536            NaN  2024-01-03T13:29:46Z  2024   NaN
# 20537            NaN  2024-01-03T13:33:28Z  2024   NaN
# 20538            NaN  2024-01-03T13:36:51Z  2024   NaN
# 20539            NaN  2024-01-03T13:37:01Z  2024   NaN
#
#                                    affiliations cites  \
# 20490                                        []   NaN
# 20491                                        []   NaN
# 20492                                        []   NaN
# 20493                                        []   NaN
# 20494                                        []   NaN
# 20495                                        []   NaN
# 20496                                        []   NaN
# 20497                                        []   NaN
# 20498                                        []   NaN
# 20499                                        []   NaN
# 20500                                        []   NaN
# 20501                                        []   NaN
# 20502                                        []   NaN
# 20503                                        []   NaN
# 20504                                        []   NaN
# 20505                                        []   NaN
# 20506                                [S0000173]   NaN
# 20507                                        []   NaN
# 20508                                        []   NaN
# 20509                                        []   NaN
# 20510                                        []   NaN
# 20511                                        []   NaN
# 20512                                        []   NaN
# 20513                                        []   NaN
# 20514                                        []   NaN
# 20515                                        []   NaN
# 20516                                        []   NaN
# 20517                                        []   NaN
# 20518                                        []   NaN
# 20519                                        []   NaN
# 20520                                        []   NaN
# 20521                                        []   NaN
# 20522                                        []   NaN
# 20523                                        []   NaN
# 20524                                        []   NaN
# 20525                                        []   NaN
# 20526                                        []   NaN
# 20527                                        []   NaN
# 20528                                        []   NaN
# 20529                                        []   NaN
# 20530                                        []   NaN
# 20531                                        []   NaN
# 20532                                        []   NaN
# 20533                                        []   NaN
# 20534                                        []   NaN
# 20535                                        []   NaN
# 20536  [S0000174, 60031828, S0000175, S0000176]   NaN
# 20537                                        []   NaN
# 20538                                        []   NaN
# 20539                                        []   NaN
#
#                                                  authors
# 20490               [S000004329, S000004330, S000004331]
# 20491               [S000004332, S000004333, S000004334]
# 20492  [S000004249, S000004248, 57208500704, S0000043...
# 20493                                       [S000004336]
# 20494                           [S000004337, S000004338]
# 20495               [S000004253, S000004254, S000004339]
# 20496   [S000004340, S000004341, S000004342, S000004343]
# 20497                           [S000004344, S000004345]
# 20498  [S000004346, S000004347, 57204546596, S0000043...
# 20499               [S000004356, S000004357, S000004358]
# 20500                           [S000004359, S000004360]
# 20501  [S000004361, S000004362, S000004363, S00000436...
# 20502  [S000004366, S000004367, S000004368, S00000436...
# 20503                           [S000004376, S000004377]
# 20504               [S000004378, S000004379, S000004380]
# 20505   [S000004381, S000004382, S000004383, S000004384]
# 20506                                       [S000004385]
# 20507  [35577656800, S000004386, S000004387, S0000043...
# 20508                           [S000004442, S000004443]
# 20509  [57200005275, S000004444, S000004445, 55749999...
# 20510  [S000004447, S000004448, S000004449, S00000445...
# 20511                           [S000004452, S000004453]
# 20512                                       [S000004259]
# 20513                           [S000004454, S000004455]
# 20514  [S000004456, S000004457, S000004458, S00000445...
# 20515               [S000004462, S000004463, S000004464]
# 20516  [S000000147, S000004465, S000000143, S00000014...
# 20517  [S000004467, S000004468, S000004469, S00000447...
# 20518               [S000004478, S000004479, S000004480]
# 20519                                       [S000004481]
# 20520  [S000004482, S000004483, S000004484, S00000448...
# 20521               [S000004490, S000004491, S000004492]
# 20522                                       [S000004493]
# 20523  [S000004494, S000004495, S000004496, 56811742900]
# 20524               [S000004497, S000004498, S000004499]
# 20525               [S000004500, S000004501, S000004502]
# 20526   [S000004503, S000004504, S000004505, S000004506]
# 20527               [S000004507, S000004508, S000004509]
# 20528                                       [S000004510]
# 20529   [S000004511, S000004512, S000004513, S000004514]
# 20530  [S000004515, S000000027, S000004516, S00000451...
# 20531                                       [S000004518]
# 20532               [S000004519, S000004520, S000004521]
# 20533               [S000004522, S000004523, S000004524]
# 20534  [S000004525, S000004526, S000004527, S00000363...
# 20535  [S000004531, S000004532, S000004533, S00000453...
# 20536                           [S000004537, S000004538]
# 20537  [S000004539, 56358154400, 55714465800, S000004...
# 20538  [S000004544, S000004545, S000004546, S00000454...
# 20539                           [S000004549, S000004550]

# %%
authors_df.tail(50)
# Out:
#              auid    given-name initials     surname   indexed-name  \
# 78757  S000004501       Menahem      NaN       Krief       Krief M.
# 78758  S000004502       Michael      NaN       Assaf       Assaf M.
# 78759  S000004503        Zeyang      NaN          Lu          Lu Z.
# 78760  S000004504          Gang      NaN        Wang        Wang G.
# 78761  S000004505          Chan      NaN          Li          Li C.
# 78762  S000004506           Zhu      NaN         Cao         Cao Z.
# 78763  S000004507       Anirudh      NaN       Menon       Menon A.
# 78764  S000004508  Unnikrishnan      NaN       Menon       Menon U.
# 78765  S000004509       Kailash      NaN     Ahirwar     Ahirwar K.
# 78766  S000004510     Chirantan      NaN         Das         Das C.
# 78767  S000004511           Wei      NaN         Yao         Yao W.
# 78768  S000004512       Hongwen      NaN       Zhang       Zhang H.
# 78769  S000004513       Yunlian      NaN         Sun         Sun Y.
# 78770  S000004514        Jinhui      NaN        Tang        Tang J.
# 78771  S000004515       Mao-Rui      NaN         Cai         Cai M.
# 78772  S000004516       Zi-Qian      NaN       Cheng       Cheng Z.
# 78773  S000004517      Teng-Fei      NaN         Yan         Yan T.
# 78774  S000004518         Moshe      NaN      Sipper      Sipper M.
# 78775  S000004519       Valerie      NaN      Vaquet      Vaquet V.
# 78776  S000004520        Fabian      NaN      Hinder      Hinder F.
# 78777  S000004521       Barbara      NaN      Hammer      Hammer B.
# 78778  S000004522        Thomas      NaN        Lips        Lips T.
# 78779  S000004523  Victor-Louis      NaN     Gusseme     Gusseme V.
# 78780  S000004524       Francis      NaN     wyffels     wyffels F.
# 78781  S000004525      Shangmin      NaN         Guo         Guo S.
# 78782  S000004526        Haoran      NaN          Bu          Bu H.
# 78783  S000004527      Haochuan      NaN        Wang        Wang H.
# 78784  S000004528        Dianbo      NaN         Sui         Sui D.
# 78785  S000004529        Yuming      NaN       Shang       Shang Y.
# 78786  S000004530        Siting      NaN          Lu          Lu S.
# 78787  S000004531           Fan      NaN         Liu         Liu F.
# 78788  S000004532       Tianshu      NaN       Zhang       Zhang T.
# 78789  S000004533        Wenwen      NaN         Dai         Dai W.
# 78790  S000004534        Wenwen      NaN         Cai         Cai W.
# 78791  S000004535      Xiaocong      NaN        Zhou        Zhou X.
# 78792  S000004536        Delong      NaN        Chen        Chen D.
# 78793  S000004537        Rachel      NaN  Pillsworth  Pillsworth R.
# 78794  S000004538         Ralph      NaN     Pudritz     Pudritz R.
# 78795  S000004539         Ruoyu      NaN       Zhang       Zhang R.
# 78796  S000004540            Yi      NaN         Lou         Lou Y.
# 78797  S000004541        Yulong      NaN         Gao         Gao Y.
# 78798  S000004542           Wen      NaN          Wu          Wu W.
# 78799  S000004543       Derrick      NaN          Ng          Ng D.
# 78800  S000004544        Xinran      NaN        Wang        Wang X.
# 78801  S000004545        Qiujie      NaN          Lu          Lu Q.
# 78802  S000004546    Dongmyoung      NaN         Lee         Lee D.
# 78803  S000004547      Zhongxue      NaN         Gan         Gan Z.
# 78804  S000004548       Nicolas      NaN       Rojas       Rojas N.
# 78805  S000004549         Klaus      NaN      Heeger      Heeger K.
# 78806  S000004550         Danny      NaN    Hermelin    Hermelin D.
#
#        affliation           paper                               affiliation
# 78757         NaN  [2401.01726v1]                                [S0000173]
# 78758         NaN  [2401.01726v1]                                [S0000173]
# 78759         NaN  [2401.01727v1]                                [S0000173]
# 78760         NaN  [2401.01727v1]                                [S0000173]
# 78761         NaN  [2401.01727v1]                                [S0000173]
# 78762         NaN  [2401.01727v1]                                [S0000173]
# 78763         NaN  [2401.01728v2]                                [S0000173]
# 78764         NaN  [2401.01728v2]                                [S0000173]
# 78765         NaN  [2401.01728v2]                                [S0000173]
# 78766         NaN  [2401.01729v1]                                [S0000173]
# 78767         NaN  [2401.01730v1]                                [S0000173]
# 78768         NaN  [2401.01730v1]                                [S0000173]
# 78769         NaN  [2401.01730v1]                                [S0000173]
# 78770         NaN  [2401.01730v1]                                [S0000173]
# 78771         NaN  [2401.01731v3]                                [S0000173]
# 78772         NaN  [2401.01731v3]                                [S0000173]
# 78773         NaN  [2401.01731v3]                                [S0000173]
# 78774         NaN  [2401.01732v1]                                [S0000173]
# 78775         NaN  [2401.01733v1]                                [S0000173]
# 78776         NaN  [2401.01733v1]                                [S0000173]
# 78777         NaN  [2401.01733v1]                                [S0000173]
# 78778         NaN  [2401.01734v2]                                [S0000173]
# 78779         NaN  [2401.01734v2]                                [S0000173]
# 78780         NaN  [2401.01734v2]                                [S0000173]
# 78781         NaN  [2401.01735v1]                                [S0000173]
# 78782         NaN  [2401.01735v1]                                [S0000173]
# 78783         NaN  [2401.01735v1]                                [S0000173]
# 78784         NaN  [2401.01735v1]                                [S0000173]
# 78785         NaN  [2401.01735v1]                                [S0000173]
# 78786         NaN  [2401.01735v1]                                [S0000173]
# 78787         NaN  [2401.01736v2]                                [S0000173]
# 78788         NaN  [2401.01736v2]                                [S0000173]
# 78789         NaN  [2401.01736v2]                                [S0000173]
# 78790         NaN  [2401.01736v2]                                [S0000173]
# 78791         NaN  [2401.01736v2]                                [S0000173]
# 78792         NaN  [2401.01736v2]                                [S0000173]
# 78793         NaN  [2401.01737v1]                                [S0000174]
# 78794         NaN  [2401.01737v1]  [S0000174, 60031828, S0000175, S0000176]
# 78795         NaN  [2401.01738v1]  [S0000174, 60031828, S0000175, S0000176]
# 78796         NaN  [2401.01738v1]  [S0000174, 60031828, S0000175, S0000176]
# 78797         NaN  [2401.01738v1]  [S0000174, 60031828, S0000175, S0000176]
# 78798         NaN  [2401.01738v1]  [S0000174, 60031828, S0000175, S0000176]
# 78799         NaN  [2401.01738v1]  [S0000174, 60031828, S0000175, S0000176]
# 78800         NaN  [2401.01739v2]  [S0000174, 60031828, S0000175, S0000176]
# 78801         NaN  [2401.01739v2]  [S0000174, 60031828, S0000175, S0000176]
# 78802         NaN  [2401.01739v2]  [S0000174, 60031828, S0000175, S0000176]
# 78803         NaN  [2401.01739v2]  [S0000174, 60031828, S0000175, S0000176]
# 78804         NaN  [2401.01739v2]  [S0000174, 60031828, S0000175, S0000176]
# 78805         NaN  [2401.01740v1]  [S0000174, 60031828, S0000175, S0000176]
# 78806         NaN  [2401.01740v1]  [S0000174, 60031828, S0000175, S0000176]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

a = np.array([[1,2],[3,4],[5,6]])
a[0].reshape(1, -1)
# Out:
# array([[1, 2]])

# %%
def get_row_cosine_similarity(matrix, row_index):
    row_vector = matrix[row_index].reshape(1, -1)  # Reshape to 2D array
    similarity = cosine_similarity(row_vector, matrix)  # Compute similarity
    return similarity.flatten()  # Flatten the result to a 1D array

# %%
get_row_cosine_similarity(a, 0)
# Out:
# array([1.        , 0.98386991, 0.97341717])
